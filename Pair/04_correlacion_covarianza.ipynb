# %%
import numpy as np
import pandas as pd
import random 

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,8) # para establecer el tamaño de todas las figuras del jupyter al mismo tamaño. 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### ¿Qué diferencia hay entre la covarianza y la correlación?
#
# La covarianza nos indica si ambas variables varian en la misma dirección (covarianza positiva) o en distinta dirección (covarianza negativa).
#
# La correlación, además de esto, nos indica la fuerza de esa relación. Varía entre -1 y 1

# %%
# Cargamos el csv
df = pd.read_csv("../ficheros/diamons_01.csv", index_col= 0)
df.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %% [markdown]
# ### Calculamos la covarianza y correlación del dataset

# %%
# Hacemos primero el pairplot, para ver la relación visualmente
sns.pairplot(df)

# %%
# Calculamos la covarianza
df.cov()
# Out:
#             carat      depth       table         price            x  \
# carat    0.145593   0.024830    0.155806  9.673445e+02     0.371924
# depth    0.024830   2.034582   -0.933329  1.492124e+01    -0.023172
# table    0.155806  -0.933329    4.962274  7.822706e+02     0.426745
# price  967.344486  14.921242  782.270560  7.638907e+06  2458.418199
# x        0.371924  -0.023172    0.426745  2.458418e+03     0.982474
# y        0.368709  -0.027858    0.408292  2.444738e+03     0.973500
# z        0.230092   0.102082    0.204198  1.513419e+03     0.602124
#
#                  y            z
# carat     0.368709     0.230092
# depth    -0.027858     0.102082
# table     0.408292     0.204198
# price  2444.737930  1513.418707
# x         0.973500     0.602124
# y         0.967829     0.597371
# z         0.597371     0.376848

# %%
# Calculamos la correlación
df.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.045622  0.183305  0.917265  0.983383  0.982232  0.982309
# depth  0.045622  1.000000 -0.293736  0.003785 -0.016390 -0.019852  0.116581
# table  0.183305 -0.293736  1.000000  0.127058  0.193271  0.186308  0.149324
# price  0.917265  0.003785  0.127058  1.000000  0.897387  0.899119  0.891991
# x      0.983383 -0.016390  0.193271  0.897387  1.000000  0.998335  0.989561
# y      0.982232 -0.019852  0.186308  0.899119  0.998335  1.000000  0.989150
# z      0.982309  0.116581  0.149324  0.891991  0.989561  0.989150  1.000000

# %% [markdown]
# Podemos observar tanto visualmente, como con la correlación y la covarianza, que carat (quilates) x (ancho), la y(alto) y la z(profundidad) están fuertemente relacionadas, casi llegando a 1, con una relación positiva. Cuanto mayor es uno, mayor son los otros.
#
# Depth (porcentaje de profundidad) y table (base) no están relacionados significativamente con ninguna otra variable ni entre ellos.
#
# Y price, que sería nuestra columna respuesta, está realacionada con todos menos con depth y table. Con carat, x, y y z tiene una fuerte relación positiva. A mayores son, mayor es el precio.

# %% [markdown]
# ### Cread un heatmap con la correlación del ejercicio anterior

# %%
sns.heatmap(df.corr(), annot= True)
# Con savefig, guardamos el heatmap
plt.savefig("../ficheros/heatmap.png");

# %% [markdown]
# En el heatmap vemos visualmente los resultados obtenidos con la correlación
