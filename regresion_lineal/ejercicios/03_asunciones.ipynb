# %% [markdown]
# # Independencia de las variables

# %%
import numpy as np
import pandas as pd
import random 

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import researchpy as rp
from scipy.stats import levene

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (10,8)

# %% [markdown]
# El objetivo de este pair programming es que evaluar si nuestro set de datos cumple todas las asunciones que se deben cumplir para hacer una regresión lineal.
#
# La **Normalidad** ya la evaluamos en el pair 02_test_estadisticos (nuestra variable respuesta no cumple la asunción de normalidad)

# %%
# Cargamos el archivo
df = pd.read_csv("../ficheros/diamons_01.csv", index_col= 0).reset_index(drop= True)
df.head(2)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
# Hacemos un info para recordarnos los datos que teníamos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50242 entries, 0 to 50241
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50242 non-null  float64
#  1   cut      50242 non-null  object
#  2   color    50242 non-null  object
#  3   clarity  50242 non-null  object
#  4   depth    50242 non-null  float64
#  5   table    50242 non-null  float64
#  6   price    50242 non-null  int64
#  7   x        50242 non-null  float64
#  8   y        50242 non-null  float64
#  9   z        50242 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.8+ MB

# %% [markdown]
# ### ASUNCIÓN DE INDEPENDENCIA

# %%
# Creamos un dataframe solo con las variables numéricas, excepto price, que es nuestra variable respuesta
df_num = df.select_dtypes(include= np.number).drop("price", axis = 1)
df_num.head(2)
# Out:
#    carat  depth  table     x     y     z
# 0   0.23   61.5   55.0  3.95  3.98  2.43
# 1   0.21   59.8   61.0  3.89  3.84  2.31

# %%
# Para las variables numéricas hacemos la correlación de Pearson para comprobar la asunción de independencia
df_num.corr()
# Out:
#           carat     depth     table         x         y         z
# carat  1.000000  0.045622  0.183305  0.983383  0.982232  0.982309
# depth  0.045622  1.000000 -0.293736 -0.016390 -0.019852  0.116581
# table  0.183305 -0.293736  1.000000  0.193271  0.186308  0.149324
# x      0.983383 -0.016390  0.193271  1.000000  0.998335  0.989561
# y      0.982232 -0.019852  0.186308  0.998335  1.000000  0.989150
# z      0.982309  0.116581  0.149324  0.989561  0.989150  1.000000

# %% [markdown]
# Vemos que *carat* (quilates), *x* (ancho), *y* (alto) y *z* (profundidad) están fuertemente relacionadas entre ellas con una relación positiva. Y no están relacionados con *depth* y *table*, lo que nos parece extraño porque *depth* sí que debería estarlo
#
# *Depth* y *table* no están relacionadas con ninguna otra ni entre sí.
#
# *Depth* y *table* sí cumplen la asunción de independencia entre ellas y con las demás, mientras que el resto no

# %%
# Hacemos un dataframe solo con las columnas categóricas
df_cat = df.select_dtypes(include= "object")
df_cat.head(2)
# Out:
#        cut color clarity
# 0    Ideal     E     SI2
# 1  Premium     E     SI1

# %% [markdown]
# Para comprobar la asunción de independencia con las columnas categóricas, hacemos un crosstab

# %%
# Primero haremos entre cut y color
crosstab, test_results, expected = rp.crosstab(df_cat["cut"], df_cat["color"], test= "chi-square", expected_freqs= True, prop= "cell")

# %%
# El crosstab nos muestra las frecuencias con las que aparecen la combinación de cada categoría
crosstab.head()
# Out:
#           color
# color         D     E     F     G     H     I     J    All
# cut
# Fair       0.31  0.43  0.59  0.58  0.54  0.32  0.21   2.97
# Good       1.27  1.78  1.74  1.64  1.29  0.91  0.57   9.21
# Ideal      5.45  7.54  7.20  9.13  5.77  3.77  1.59  40.46
# Premium    3.01  4.37  4.29  5.28  4.20  2.39  1.30  24.85
# Very Good  2.87  4.60  4.09  4.31  3.34  2.11  1.20  22.51

# %%
# Imprimimos por pantalla los resultados del test
test_results
# Out:
#                  Chi-square test   results
# 0  Pearson Chi-square ( 24.0) =   270.9933
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0367

# %% [markdown]
# **H0 sería que son independientes**
#
# Entre *cut* y *color*, como el p-valor es menor que 0.05, entonces podemos rechazar la H0, lo que quiere decir que son dependientes. Lo mismo nos indica la V de Crammer, que está entre 0 y 0.1
#
# No cumplen la asunción de independencia

# %%
# Ahora haremos entre cut y clarity
crosstab2, test_results2, expected2 = rp.crosstab(df_cat["cut"], df_cat["clarity"], test= "chi-square", expected_freqs= True, prop= "cell")

# %%
crosstab2
# Out:
#           clarity
# clarity        I1    IF    SI1    SI2    VS1    VS2  VVS1  VVS2     All
# cut
# Fair         0.40  0.02   0.77   0.82   0.31   0.48  0.03  0.13    2.97
# Good         0.18  0.12   2.95   1.97   1.22   1.83  0.37  0.55    9.21
# Ideal        0.28  2.30   8.01   4.67   6.81   9.55  3.92  4.92   40.46
# Premium      0.39  0.42   6.53   5.04   3.61   6.04  1.17  1.65   24.85
# Very Good    0.16  0.48   6.11   3.77   3.34   4.75  1.53  2.37   22.51
# All          1.41  3.35  24.37  16.27  15.29  22.66  7.02  9.63  100.00

# %%
test_results2
# Out:
#                  Chi-square test    results
# 0  Pearson Chi-square ( 28.0) =   4096.8143
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.1428

# %% [markdown]
# *Cut* y *clarity* :
# - Como el p-valor es menor que 0.05, entonces podemos rechazar la H0, lo que quiere decir que son dependientes.
# - Lo mismo nos indica la V de Crammer, que está entre 0.1 y 0.3
#
# No cumplen la asunción de independencia

# %%
# Ahora haremos entre color y clarity
crosstab3, test_results3, expected3 = rp.crosstab(df_cat["color"], df_cat["clarity"], test= "chi-square", expected_freqs= True, prop= "cell")

# %%
crosstab3.head()
# Out:
#         clarity
# clarity      I1    IF   SI1   SI2   VS1   VS2  VVS1  VVS2    All
# color
# D          0.08  0.09  4.00  2.60  1.37  3.28  0.47  1.03  12.91
# E          0.20  0.28  4.66  3.21  2.46  4.73  1.26  1.92  18.72
# F          0.28  0.72  4.02  2.96  2.59  4.07  1.39  1.87  17.91
# G          0.29  1.31  3.76  2.72  3.94  4.27  1.91  2.72  20.93
# H          0.30  0.57  4.12  2.62  2.21  3.04  1.15  1.14  15.14

# %%
test_results3
# Out:
#                  Chi-square test    results
# 0  Pearson Chi-square ( 42.0) =   1994.6050
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.0813

# %% [markdown]
# *Color* y *clarity* :
# - Como el p-valor es menor que 0.05, entonces podemos rechazar la H0, lo que quiere decir que son dependientes.
# - Lo mismo nos indica la V de Crammer, que está entre 0 y 0.1
#
# No cumplen la asunción de independencia

# %% [markdown]
# ## Homogeneidad de varianzas

# %%
# Primero lo intentaremos ver visualmente de las variables categóricas, con un violinplot
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(15, 15))
for i, col in enumerate(df_cat.columns):
    sns.violinplot(
    x       = col,
    y       = 'price',
    data    = df,
    palette = 'tab10',
    ax= ax[i])
    ax[i].set_title(f"Distribucion de precios por {col}")
    ax[i].set_ylabel("precio")
    ax[i].set_xlabel(col);

# %%
# Intentamos lo mismo con un boxplot
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(15, 15))
for i, col in enumerate(df_cat.columns):
    sns.boxplot(
    x       = col,
    y       = 'price',
    data    = df,
    palette = 'tab10',
    ax= ax[i])
    ax[i].set_title(f"Distribucion de precios por {col}")
    ax[i].set_ylabel("precio")
    ax[i].set_xlabel(col);

# %% [markdown]
# Aquí hacemos un análisis visual solamente, luego lo confirmaremos o no analíticamente
# - Respecto a *cut*:
#
#     En el violinplot y en el boxplot parece que no hay mucha diferencia entre las medianas.
#
# - Respecto al *color*:
#
#     Algunos colores parecen más homogeneos (E, F, G Y D), pero entre otros como el E y el J no hay nada que ver
#
# - Respecto a *clarity*:
#
#     Algunas parecen heterogeneas, y otras categorías parecen estar más igualadas

# %%
# Hacemos ahora las gráficas para las variables numéricas
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (10, 10))

axes = axes.flat

for i, colum in enumerate(df_num.columns): 
    sns.regplot(
        data = df,
        x = colum,
        y = 'price',
        line_kws = {"color": "black", "alpha": 0.7 }, 
        ax = axes[i])
    
    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")

    # establecemos que no queremos que aparezca nada en el eje x
    axes[i].set_xlabel("")
    
# ajustamos el tamaño de cada subplot para que no se vean superpuestos. 
fig.tight_layout();

# %% [markdown]
# Como podemos ver, graficamente parece que no se cumple la asunción de homocedasticidad para ninguna de las variables predictoras

# %% [markdown]
# Comprobamos ahora analíticamente, primero para las variables categóricas

# %%
# Realizamos una función para crear los distintos dataframes que necesitaremos pasarle al test de levene
# Tendremos que pasarle la columna que queramos y el dataframe
def test_levene_cat(col, dataf):
    # Creamos una lista con los valores únicos de la variable
    lista = dataf[col].unique()
    # Creamos una lista donde apendearemos los dataframes
    lista_df = []
    # Iteramos por la lista de valores únicos
    for i in lista:
        # Creamos dataframes con la columna price filtrada por la condición de que la variable que le pasamos sea igual a i (valor único)
        lista_df.append(dataf[dataf[col] == i]["price"])
    # Nos devuelve dos parametros, la lista de los datrafames y la longitud de la lista
    return lista_df, len(lista_df)

# %%
# Llamamos a la función para la columna color
lista_color, long_color = test_levene_cat("color", df)

# %%
# Comprobamos la longitud para saber cuantas veces tenemos que pasar la lista
long_color
# Out:
# 7

# %%
# Realizamos el test de levene
levene_test = stats.levene(lista_color[0],lista_color[1], lista_color[2], lista_color[3], lista_color[4], lista_color[5], lista_color[6], center= "median")
levene_test
# Out:
# LeveneResult(statistic=167.1458698892004, pvalue=2.86871655646127e-211)

# %%
# Hacemos lo mismo para la variable cut
lista_cut, long_cut = test_levene_cat("cut", df)

# %%
long_cut
# Out:
# 5

# %%
levene_test = stats.levene(lista_cut[0],lista_cut[1], lista_cut[2], lista_cut[3], lista_cut[4], center= "median")
levene_test
# Out:
# LeveneResult(statistic=108.87959986555289, pvalue=1.4866054193389799e-92)

# %%
# Hacemos lo mismo para clarity
lista_clarity, long_clarity = test_levene_cat("clarity", df)

# %%
long_clarity
# Out:
# 8

# %%
levene_test = stats.levene(lista_clarity[0],lista_clarity[1], lista_clarity[2], lista_clarity[3], lista_clarity[4], lista_clarity[5], lista_clarity[6], lista_clarity[7], center= "median")
levene_test
# Out:
# LeveneResult(statistic=102.172385702773, pvalue=4.362410858436878e-149)

# %% [markdown]
# **H0: Hay homogeneidad en las varianzas**
#
# Podemos observar que para todas las variables categóricas el p-valor es menor que 0.05, por lo que tampoco cumplen la asunción de homocedasticidad.

# %% [markdown]
# Hacemos ahora para las variables númericas

# %%
# Creamos un diccionario para añadirle los resultados
resultados = {}
for col in df_num.columns:
    # Iteramos por la lista de las columnas del dataframe numericas sin la variable respuesta y realizamos el test de levene para cada columna
    statistic, p_val = levene(df[col], df["price"], center= "median")
    resultados[col] = p_val

# %%
resultados
# Out:
# {'carat': 0.0, 'depth': 0.0, 'table': 0.0, 'x': 0.0, 'y': 0.0, 'z': 0.0}

# %% [markdown]
# Todos los valores para el test de Levene con las variables numéricas son menores que 0.05. Por lo tanto no hay homogeneidad en las varianzas.
